# %% [markdown]
# <a href="https://colab.research.google.com/github/satria080503/MachineLearning_Ganjil2023/blob/main/Assignment_Week_2_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab Assignment**

# %% [markdown]
# ## **Assignment Description**

# %% [markdown]
# In this practical assignment, you will be using the "Wisconsin Breast Cancer" dataset. The dataset consists of 569 instances used for diagnosing Malignant (M) and Benign (B) cancer types. Your tasks are as follows:
# 1. Separate the variables that can be used and the ones that cannot be used.
# 2. Perform encoding on the "diagnosis" column.
# 3. Standardize all columns with numeric values.
# 4. Perform a stratified split of the data to create training and test data with an 80:20 ratio.

# %% [markdown]
# ---

# %% [markdown]
# ## **Data**

# %% [markdown]
# you can download in this drive :
#
# https://drive.google.com/file/d/1qUnwMy2gZOtW6QBA-bpozIseWI37CPWA/view?usp=sharing

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Answer**

# %% [markdown]
# **load the data**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

data = '/content/wbc.csv' # path dataset
df = pd.read_csv(data) # load dataset

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# 1. Separate the variables that can be used and the ones that cannot be used.

# %%
# check the total null data ()
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Get the list of variables
variables = list(df.columns)

print("Variables:")
for variable in variables:
    print(variable)
print("")
print("variable cannot be used : 'id','Unnamed : 32'")

# Remove the ID number and Unnamed variables
variables_to_use = [variable for variable in variables if variable not in ["id", "Unnamed: 32"]]

print("variable to use : ",variables_to_use)
# Out:
# Variables:
# id
# diagnosis
# radius_mean
# texture_mean
# perimeter_mean
# area_mean
# smoothness_mean
# compactness_mean
# concavity_mean
# concave points_mean
# symmetry_mean
# fractal_dimension_mean
# radius_se
# texture_se
# perimeter_se
# area_se
# smoothness_se
# compactness_se
# concavity_se
# concave points_se
# symmetry_se
# fractal_dimension_se
# radius_worst
# texture_worst
# perimeter_worst
# area_worst
# smoothness_worst
# compactness_worst
# concavity_worst
# concave points_worst
# symmetry_worst
# fractal_dimension_worst
# Unnamed: 32
#
# variable cannot be used : 'id','Unnamed : 32'
# ...

# %%
df = df[variables_to_use]
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# 2. Perform encoding on the "diagnosis" column.

# %%
le = LabelEncoder() # initiate LabelEncoder object
df['diagnosis'] = le.fit_transform(df['diagnosis']) # encoding

df.head(10)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1     1.097064     -2.073335        1.269934   0.984375
# 1          1     1.829821     -0.353632        1.685955   1.908708
# 2          1     1.579888      0.456187        1.566503   1.558884
# 3          1    -0.768909      0.253732       -0.592687  -0.764464
# 4          1     1.750297     -1.151816        1.776573   1.826229
# 5          1    -0.476375     -0.835335       -0.387148  -0.505650
# 6          1     1.170908      0.160649        1.138125   1.095295
# 7          1    -0.118517      0.358450       -0.072867  -0.218965
# 8          1    -0.320167      0.588830       -0.184080  -0.384207
# 9          1    -0.473535      1.105439       -0.329482  -0.509063
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# ...

# %% [markdown]
# 3. Standardize all columns with numeric values.

# %%
# Create an instance of StandardScaler
std = StandardScaler()

# Iterate through each column in variables_to_use and standardize them
for column_name in variables_to_use:
    df[column_name] = std.fit_transform(df[[column_name]])

df.head(10)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   1.297676     1.097064     -2.073335        1.269934   0.984375
# 1   1.297676     1.829821     -0.353632        1.685955   1.908708
# 2   1.297676     1.579888      0.456187        1.566503   1.558884
# 3   1.297676    -0.768909      0.253732       -0.592687  -0.764464
# 4   1.297676     1.750297     -1.151816        1.776573   1.826229
# 5   1.297676    -0.476375     -0.835335       -0.387148  -0.505650
# 6   1.297676     1.170908      0.160649        1.138125   1.095295
# 7   1.297676    -0.118517      0.358450       -0.072867  -0.218965
# 8   1.297676    -0.320167      0.588830       -0.184080  -0.384207
# 9   1.297676    -0.473535      1.105439       -0.329482  -0.509063
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# ...

# %% [markdown]
# 4. Perform a stratified split of the data to create training and test data with an 80:20 ratio.

# %%
# Split data
from sklearn.model_selection import train_test_split

# Split data training dan dan lainnya
# data lainnya, akan kita split lagi menjadi validasi dan testing.
# Rasio yang akan kita gunakan adalah 8:1:1
df_train, df_unseen = train_test_split(df, test_size=0.2, random_state=0, stratify=df['diagnosis'])

# Split lagi antara validasi dan testing
df_val, df_test = train_test_split(df_unseen, test_size=0.5, random_state=0, stratify=df_unseen['diagnosis'])

# Cek masing-masing ukuran data
print("-------------------------------------------------------------")
print(f'Number of original data labels :\n{df.diagnosis.value_counts()}')
print("-------------------------------------------------------------")
print(f'Number of data train labels :\n{df_train.diagnosis.value_counts()}')
print("-------------------------------------------------------------")
print(f'Number of data val labels :\n{df_val.diagnosis.value_counts()}')
print("-------------------------------------------------------------")
print(f'Number of data test labels :\n{df_test.diagnosis.value_counts()}')
print("-------------------------------------------------------------")
# Out:
# -------------------------------------------------------------
# Number of original data labels :
# 0    357
# 1    212
# Name: diagnosis, dtype: int64
# -------------------------------------------------------------
# Number of data train labels :
# 0    285
# 1    170
# Name: diagnosis, dtype: int64
# -------------------------------------------------------------
# Number of data val labels :
# 0    36
# 1    21
# Name: diagnosis, dtype: int64
# -------------------------------------------------------------
# Number of data test labels :
# 0    36
# 1    21
# Name: diagnosis, dtype: int64
# -------------------------------------------------------------
